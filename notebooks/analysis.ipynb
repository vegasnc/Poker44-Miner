# %% [markdown]
# # Poker44 Benchmark Analysis
#
# Use this notebook for exploratory analysis of cached benchmark releases, feature distributions, and per-release model performance.

# %%
from src.data.loader import BenchmarkClient, iter_examples_from_records
from src.features.engineering import FeaturePipeline

client = BenchmarkClient()
releases = client.releases(limit=3)
releases
